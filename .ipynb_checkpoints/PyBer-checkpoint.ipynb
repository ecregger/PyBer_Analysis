# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
# Import NumPy and the stats module from SciPy.
import numpy as np
import scipy.stats as sts

# %%
city_data_to_load = "Resources/city_data.csv"
ride_data_to_load = "Resources/ride_data.csv"

# %%
city_data_df = pd.read_csv(city_data_to_load)
city_data_df.head(10)
# Out:
#             city  driver_count   type
# 0    Richardfort            38  Urban
# 1   Williamsstad            59  Urban
# 2    Port Angela            67  Urban
# 3     Rodneyfort            34  Urban
# 4    West Robert            39  Urban
# 5   West Anthony            70  Urban
# 6    West Angela            48  Urban
# 7  Martinezhaven            25  Urban
# 8      Karenberg            22  Urban
# 9    Barajasview            26  Urban

# %%
ride_data_df = pd.read_csv(ride_data_to_load)
ride_data_df.head(10)
# Out:
#                  city                 date   fare        ride_id
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
# 5        South Latoya  2019-03-11 12:26:48   9.52  1994999424437
# 6       New Paulville  2019-02-27 11:17:56  43.25   793208410091
# 7        Simpsonburgh  2019-04-26 00:43:24  35.98   111953927754
# 8     South Karenland  2019-01-08 03:28:48  35.09  7995623208694
# 9       North Jasmine  2019-03-09 06:26:29  42.81  5327642267789

# %%
city_data_df.count()
# Out:
# city            120
# driver_count    120
# type            120
# dtype: int64

# %%
city_data_df.isnull().sum()
# Out:
# city            0
# driver_count    0
# type            0
# dtype: int64

# %%
city_data_df.dtypes
# Out:
# city            object
# driver_count     int64
# type            object
# dtype: object

# %%
city_data_df['type'].unique()
# Out:
# array(['Urban', 'Suburban', 'Rural'], dtype=object)

# %%
sum(city_data_df['type'] == 'Urban')
# Out:
# 66

# %%
sum(city_data_df['type'] == 'Suburban')
# Out:
# 36

# %%
sum(city_data_df['type'] == 'Rural')
# Out:
# 18

# %%
ride_data_df.count()
# Out:
# city       2375
# date       2375
# fare       2375
# ride_id    2375
# dtype: int64

# %%
ride_data_df.isnull().sum()
# Out:
# city       0
# date       0
# fare       0
# ride_id    0
# dtype: int64

# %%
ride_data_df.dtypes
# Out:
# city        object
# date        object
# fare       float64
# ride_id      int64
# dtype: object

# %%
pyber_data_df = pd.merge(ride_data_df, city_data_df, how='left', on=['city', 'city'])
pyber_data_df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %%
urban_cities_df = pyber_data_df[pyber_data_df['type'] == "Urban"]
urban_cities_df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %%
suburban_cities_df = pyber_data_df[pyber_data_df['type'] == "Suburban"]
rural_cities_df = pyber_data_df[pyber_data_df['type'] == "Rural"]
rural_cities_df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 2250   Randallchester  2019-04-13 11:13:31  43.22  1076079536213
# 2251      North Holly  2019-02-02 14:54:00  12.42  1985256326182
# 2252      Michaelberg  2019-03-27 18:27:34  54.85  4421836952718
# 2253  Lake Latoyabury  2019-02-23 21:12:24  47.90  3269652929887
# 2254  Lake Latoyabury  2019-05-06 08:57:56  51.80  4018025271936
#
#       driver_count   type
# 2250             9  Rural
# 2251             8  Rural
# 2252             6  Rural
# 2253             2  Rural
# 2254             2  Rural

# %%
urban_ride_count = urban_cities_df.groupby(['city']).count()['ride_id']
urban_ride_count.head()
# Out:
# city
# Amandaburgh        18
# Barajasview        22
# Carriemouth        27
# Christopherfurt    27
# Deanville          19
# Name: ride_id, dtype: int64

# %%
suburban_ride_count = suburban_cities_df.groupby(['city']).count()['ride_id']
rural_ride_count = rural_cities_df.groupby(['city']).count()['ride_id']

# %%
urban_avg_fare = urban_cities_df.groupby(['city']).mean()['fare']
suburban_avg_fare = suburban_cities_df.groupby(['city']).mean()['fare']
rural_avg_fare = rural_cities_df.groupby(['city']).mean()['fare']
# Out:
# C:\Users\ecreg\AppData\Local\Temp\ipykernel_4272\2617547686.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   urban_avg_fare = urban_cities_df.groupby(['city']).mean()['fare']
# C:\Users\ecreg\AppData\Local\Temp\ipykernel_4272\2617547686.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   suburban_avg_fare = suburban_cities_df.groupby(['city']).mean()['fare']
# C:\Users\ecreg\AppData\Local\Temp\ipykernel_4272\2617547686.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   rural_avg_fare = rural_cities_df.groupby(['city']).mean()['fare']

# %%
urban_driver_count = urban_cities_df.groupby(['city']).mean()['driver_count']
suburban_driver_count = suburban_cities_df.groupby(['city']).mean()['driver_count']
rural_driver_count = rural_cities_df.groupby(['city']).mean()['driver_count']
# Out:
# C:\Users\ecreg\AppData\Local\Temp\ipykernel_4272\4075125251.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   urban_driver_count = urban_cities_df.groupby(['city']).mean()['driver_count']
# C:\Users\ecreg\AppData\Local\Temp\ipykernel_4272\4075125251.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   suburban_driver_count = suburban_cities_df.groupby(['city']).mean()['driver_count']
# C:\Users\ecreg\AppData\Local\Temp\ipykernel_4272\4075125251.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   rural_driver_count = rural_cities_df.groupby(['city']).mean()['driver_count']

# %%
plt.scatter(urban_ride_count, urban_avg_fare, s=10*urban_driver_count, c='coral', edgecolor = 'black', linewidths=1, alpha=0.8, label='Urban')
plt.title("PyBer Ride-Sharing Data (2019)")
plt.ylabel("Average Fare ($)")
plt.xlabel("Total Number of Rides (Per City)")
plt.grid(True)
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %%
# Build the scatter plots for suburban cities.
plt.scatter(suburban_ride_count,
      suburban_avg_fare,
      s=10*suburban_driver_count, c="skyblue",
      edgecolor="black", linewidths=1,
      alpha=0.8, label="Suburban")
plt.title("PyBer Ride-Sharing Data (2019)")
plt.ylabel("Average Fare ($)")
plt.xlabel("Total Number of Rides (Per City)")
plt.grid(True)
# Add the legend.
plt.legend()

# %%
# Build the scatter plots for rural cities.
plt.scatter(rural_ride_count,
      rural_avg_fare,
      s=10*rural_driver_count, c="gold",
      edgecolor="black", linewidths=1,
      alpha=0.8, label="Rural")
plt.title("PyBer Ride-Sharing Data (2019)")
plt.ylabel("Average Fare ($)")
plt.xlabel("Total Number of Rides (Per City)")
plt.grid(True)
# Add the legend.
plt.legend()

# %%
plt.subplots(figsize=(10,6))

plt.scatter(urban_ride_count,
      urban_avg_fare,
      s=10*urban_driver_count, c="coral",
      edgecolor="black", linewidths=1,
      alpha=0.8, label="Urban")

plt.scatter(suburban_ride_count,
      suburban_avg_fare,
      s=10*suburban_driver_count, c="skyblue",
      edgecolor="black", linewidths=1,
      alpha=0.8, label="Suburban")

plt.scatter(rural_ride_count,
      rural_avg_fare,
      s=10*rural_driver_count, c="gold",
      edgecolor="black", linewidths=1,
      alpha=0.8, label="Rural")

plt.title("PyBer Ride-Sharing Data (2019)", fontsize=20)
plt.ylabel("Average Fare ($)", fontsize=12)
plt.xlabel("Total Number of Rides (Per City)", fontsize=12)
plt.grid(True)

lgnd = plt.legend(fontsize="12", mode="Expanded", scatterpoints=1, loc="best", title="City Types")
lgnd.legendHandles[0]._sizes = [75]
lgnd.legendHandles[1]._sizes = [75]
lgnd.legendHandles[2]._sizes = [75]

lgnd.get_title().set_fontsize(12)

plt.text(42, 35, "Note:Circle size correlates with driver count per city.", fontsize="12")

# Show the plot

plt.savefig("analysis/Fig1.png")

plt.show()

# %%
urban_cities_df.describe()
# Out:
#               fare       ride_id  driver_count
# count  1625.000000  1.625000e+03   1625.000000
# mean     24.525772  4.873485e+12     36.678154
# std      11.738649  2.907440e+12     20.075545
# min       4.050000  1.458810e+10      3.000000
# 25%      14.550000  2.400244e+12     22.000000
# 50%      24.640000  4.711188e+12     37.000000
# 75%      34.580000  7.451579e+12     52.000000
# max      44.970000  9.991538e+12     73.000000

# %%
urban_ride_count.describe()
# Out:
# count    66.000000
# mean     24.621212
# std       5.408726
# min      12.000000
# 25%      21.000000
# 50%      24.000000
# 75%      28.000000
# max      39.000000
# Name: ride_id, dtype: float64

# %%
suburban_ride_count.describe()
# Out:
# count    36.000000
# mean     17.361111
# std       4.323707
# min       9.000000
# 25%      14.000000
# 50%      17.000000
# 75%      19.250000
# max      27.000000
# Name: ride_id, dtype: float64

# %%
rural_ride_count.describe()
# Out:
# count    18.000000
# mean      6.944444
# std       2.508157
# min       3.000000
# 25%       5.250000
# 50%       6.000000
# 75%       8.750000
# max      12.000000
# Name: ride_id, dtype: float64

# %%
round(urban_ride_count.mean(),2), round(suburban_ride_count.mean(),2), round(rural_ride_count.mean(),2)
# Out:
# (24.62, 17.36, 6.94)

# %%
round(urban_ride_count.median(),2)
# Out:
# 24.0

# %%
urban_ride_count.mode()
# Out:
# 0    22
# 1    25
# Name: ride_id, dtype: int64

# %%
suburban_ride_count.mode()
# Out:
# 0    17
# Name: ride_id, dtype: int64

# %%
mean_urban_ride_count = np.mean(urban_ride_count)
print(f"The mean for the ride counts for urban trips is {mean_urban_ride_count:.2f}.")

median_urban_ride_count = np.median(urban_ride_count)
print(f"The median for the ride counts for urban trips is {median_urban_ride_count}.")

mode_urban_ride_count = sts.mode(urban_ride_count)
print(f"The mode for the ride counts for urban trips is {mode_urban_ride_count}.")
# Out:
# The mean for the ride counts for urban trips is 24.62.
# The median for the ride counts for urban trips is 24.0.
# The mode for the ride counts for urban trips is ModeResult(mode=array([22], dtype=int64), count=array([7])).
# C:\Users\ecreg\AppData\Local\Temp\ipykernel_4272\1694214379.py:7: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_urban_ride_count = sts.mode(urban_ride_count)

# %%
mode_suburban_ride_count = sts.mode(suburban_ride_count)
print(f"The mode for the ride counts for suburban trips is {mode_suburban_ride_count}.")
# Out:
# The mode for the ride counts for suburban trips is ModeResult(mode=array([17], dtype=int64), count=array([7])).
# C:\Users\ecreg\AppData\Local\Temp\ipykernel_4272\3599068035.py:1: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_suburban_ride_count = sts.mode(suburban_ride_count)

# %%
mode_rural_ride_count = sts.mode(rural_ride_count)
print(f"The mode for the ride counts for suburban trips is {mode_rural_ride_count}.")
# Out:
# The mode for the ride counts for suburban trips is ModeResult(mode=array([6], dtype=int64), count=array([5])).
# C:\Users\ecreg\AppData\Local\Temp\ipykernel_4272\3874040646.py:1: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_rural_ride_count = sts.mode(rural_ride_count)

# %%
urban_fares = urban_cities_df['fare']
urban_fares.head()
# Out:
# 0    13.83
# 1    30.24
# 2    33.44
# 3    23.44
# 4    34.58
# Name: fare, dtype: float64

# %%
mean_urban_fares = np.mean(urban_fares)
print(f"The mean fare price for urban trips is ${mean_urban_fares:.2f}.")

median_urban_fares = np.median(urban_fares)
print(f"The median fare price for urban trips is ${median_urban_fares:.2f}.")

mode_urban_fares = sts.mode(urban_fares)
print(f"The mode fare price for urban trips is {mode_urban_fares}.")
# Out:
# The mean fare price for urban trips is $24.53.
# The median fare price for urban trips is $24.64.
# The mode fare price for urban trips is ModeResult(mode=array([22.86]), count=array([5])).
# C:\Users\ecreg\AppData\Local\Temp\ipykernel_4272\1357058021.py:7: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_urban_fares = sts.mode(urban_fares)

# %%
suburban_fares = suburban_cities_df['fare']
suburban_fares.head()
# Out:
# 1625    27.79
# 1626    18.75
# 1627    21.71
# 1628    17.10
# 1629    37.78
# Name: fare, dtype: float64

# %%
rural_fares = rural_cities_df['fare']
rural_fares.head()
# Out:
# 2250    43.22
# 2251    12.42
# 2252    54.85
# 2253    47.90
# 2254    51.80
# Name: fare, dtype: float64

# %%
mean_suburban_fares = np.mean(suburban_fares)
print(f"The mean fare price for urban trips is ${mean_suburban_fares:.2f}.")

median_suburban_fares = np.median(suburban_fares)
print(f"The median fare price for urban trips is ${median_suburban_fares:.2f}.")

mode_suburban_fares = sts.mode(suburban_fares)
print(f"The mode fare price for urban trips is {mode_suburban_fares}.")
# Out:
# The mean fare price for urban trips is $30.97.
# The median fare price for urban trips is $30.75.
# The mode fare price for urban trips is ModeResult(mode=array([17.99]), count=array([3])).
# C:\Users\ecreg\AppData\Local\Temp\ipykernel_4272\2203204964.py:7: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_suburban_fares = sts.mode(suburban_fares)

# %%
mean_rural_fares = np.mean(rural_fares)
print(f"The mean fare price for urban trips is ${mean_rural_fares:.2f}.")

median_rural_fares = np.median(rural_fares)
print(f"The median fare price for urban trips is ${median_rural_fares:.2f}.")

mode_rural_fares = sts.mode(rural_fares)
print(f"The mode fare price for urban trips is {mode_rural_fares}.")
# Out:
# The mean fare price for urban trips is $34.62.
# The median fare price for urban trips is $37.05.
# The mode fare price for urban trips is ModeResult(mode=array([37.05]), count=array([2])).
# C:\Users\ecreg\AppData\Local\Temp\ipykernel_4272\2397965861.py:7: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode_rural_fares = sts.mode(rural_fares)

# %%
urban_drivers = urban_cities_df['driver_count']
urban_drivers.head()
# Out:
# 0     5
# 1    72
# 2    57
# 3    34
# 4    46
# Name: driver_count, dtype: int64

# %%
suburban_drivers = suburban_cities_df['driver_count']

# %%
suburban_drivers.describe()
# Out:
# count    625.000000
# mean      13.712000
# std        8.042372
# min        1.000000
# 25%        5.000000
# 50%       16.000000
# 75%       21.000000
# max       25.000000
# Name: driver_count, dtype: float64

# %%
x_labels = ['Urban', 'Suburban', 'Rural']

ride_count_data = [urban_ride_count, suburban_ride_count, rural_ride_count]

fig, ax = plt.subplots(figsize=(10,6))

ax.set_title('Ride Count Data (2019)',fontsize=20)
ax.set_ylabel('Number of Rides',fontsize=14)
ax.set_xlabel('City Types', fontsize=14)

ax.boxplot(ride_count_data, labels=x_labels)

ax.set_yticks(np.arange(1,45,step=3.0))

ax.grid()
plt.savefig('analysis/Fig2.png')
plt.show()

# %%
urban_city_outlier = urban_ride_count[urban_ride_count==39].index[0]

print(f"{urban_city_outlier} has the highest rider count.")
# Out:
# West Angela has the highest rider count.

# %%
x_labels = ["Urban", "Suburban", "Rural"]

ride_fare_data = [urban_fares, suburban_fares, rural_fares]

fig, ax = plt.subplots(figsize=(10, 6))
# Add the title, y-axis label and grid.
ax.set_title('Ride Fare Data (2019)', fontsize=20)
ax.set_ylabel('Fare($USD)',fontsize=12)
ax.set_xlabel('City Types',fontsize=12)

ax.boxplot(ride_fare_data, labels=x_labels)

ax.set_yticks(np.arange(0,70, step=5.0))


ax.grid()

plt.savefig('analysis/Fig3.png')
plt.show()
print("Summary Statistics")
urban_fares.describe()
# Out:
# Summary Statistics
# count    1625.000000
# mean       24.525772
# std        11.738649
# min         4.050000
# 25%        14.550000
# 50%        24.640000
# 75%        34.580000
# max        44.970000
# Name: fare, dtype: float64

# %%
x_labels = ["Urban", "Suburban", "Rural"]

driver_count_data = [urban_driver_count, suburban_driver_count, rural_driver_count]

fig, ax = plt.subplots(figsize=(10, 6))
# Add the title, y-axis label and grid.
ax.set_title('Driver Count Data (2019)', fontsize=20)
ax.set_ylabel('Number of Drivers',fontsize=12)
ax.set_xlabel('City Types',fontsize=12)

ax.boxplot(driver_count_data, labels=x_labels)

ax.set_yticks(np.arange(0,70, step=5.0))


ax.grid()

plt.savefig('analysis/Fig4.png')
plt.show()
print("Summary Statistics")
urban_driver_count.describe()
# Out:
# Summary Statistics
# count    66.000000
# mean     36.439394
# std      19.827819
# min       3.000000
# 25%      22.000000
# 50%      37.000000
# 75%      49.750000
# max      73.000000
# Name: driver_count, dtype: float64
